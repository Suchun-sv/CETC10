# %%
import pandas as pd
import numpy as np

# %%
class UPLOAD:
    def dian(self, df, name):
        df['JD'] = df['JD'].astype(str)
        df['WD'] = df['WD'].astype(str)
        df['new'] = df['JD']+','+df['WD']
        df.to_csv(name+'.csv', index=False)

# %%
df = pd.read_csv('Trace_All.csv')

# %%
df['JD'] = df['JD'].astype(float)
df['SD'] = df['SD'].astype(float)
df['GD'] = df['GD'].astype(float)
df['WD'] = df['WD'].astype(float)
df['JD'] = df['JD'].map(lambda x : "%.4f"%x)
df['WD'] = df['WD'].map(lambda x : "%.4f"%x)
df['GD'] = df['GD'].map(lambda x : "%.4f"%x)
df['SD'] = df['SD'].map(lambda x : "%.4f"%x)
df['JD'] = df['JD'].astype(float)
df['SD'] = df['SD'].astype(float)
df['GD'] = df['GD'].astype(float)
df['WD'] = df['WD'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280893 entries, 0 to 280892
# Data columns (total 8 columns):
# Unnamed: 0    280893 non-null int64
# ID            280893 non-null object
# WD            280893 non-null float64
# JD            280893 non-null float64
# GD            280893 non-null float64
# SD            280893 non-null float64
# SJ            280893 non-null object
# target        280893 non-null object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 17.1+ MB

# %%
df_F5 = df[df['target']=='F-1']
df_F5['JD'] = df_F5['JD'].astype(float)
df_F5['SD'] = df_F5['SD'].astype(float)
df_F5['GD'] = df_F5['GD'].astype(float)
df_F5['WD'] = df_F5['WD'].astype(float)
pass
# Out:
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_F1 = df[df['target']=='F-1']
df_F1['JD'] = df_F1['JD'].astype(float)
df_F1['SD'] = df_F1['SD'].astype(float)
df_F1['GD'] = df_F1['GD'].astype(float)
df_F1['WD'] = df_F1['WD'].astype(float)
pass
# Out:
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_R2019081303584407603967 = df_F5[df_F5['ID']=='R2019081303584407603967']

# %%
df_R2019081303584407603967
# Out:
#         Unnamed: 0                       ID       WD        JD         GD  \
# 268370      268370  R2019081303584407603967  38.9042  124.3568  5162.1492
# 268371      268371  R2019081303584407603967  38.8842  124.3429  4968.0509
# 268372      268372  R2019081303584407603967  38.8649  124.3202  5430.0555
# 268373      268373  R2019081303584407603967  38.8390  124.3286  5338.3882
# 268374      268374  R2019081303584407603967  38.8123  124.3198  5006.2216
# 268375      268375  R2019081303584407603967  38.8059  124.2987  5161.1952
# 268376      268376  R2019081303584407603967  38.7777  124.3092  4675.2917
# 268377      268377  R2019081303584407603967  38.7630  124.2859  5073.0089
# 268378      268378  R2019081303584407603967  38.7383  124.2935  5225.8325
# 268379      268379  R2019081303584407603967  38.7270  124.3094  4767.3916
# 268380      268380  R2019081303584407603967  38.6919  124.3093  4932.9261
# 268381      268381  R2019081303584407603967  38.6771  124.2905  4790.8563
# ...

# %%
df_F5_JD_WD = df_F5[['JD','WD']]
df_F5_JD_WD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2707 entries, 268370 to 271076
# Data columns (total 2 columns):
# JD    2707 non-null float64
# WD    2707 non-null float64
# dtypes: float64(2)
# memory usage: 63.4 KB

# %%
trainX = df_F5_JD_WD.values
trainX.shape
# Out:
# (2707, 2)

# %%
trainX
# Out:
# array([[124.3568,  38.9042],
#        [124.3429,  38.8842],
#        [124.3202,  38.8649],
#        ...,
#        [125.3746,  34.5214],
#        [125.3593,  34.5157],
#        [125.3699,  34.4888]])

# %% [markdown]
# # K-means

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=270)
kmeans.fit(trainX)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=270, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans_centers = pd.DataFrame(kmeans.cluster_centers_)
kmeans_centers.columns = ['JD', 'WD']

# %%
m = list()
j = 0
for i in kmeans_centers['JD']:
    flag = 0
    j = 0
    for index, jj in enumerate(df_F5['JD']):
#         print("{}".format(jj))
        if abs(jj-i)<0.00015:
            if flag:
                pass
#                 print("{},{},{}出事了".format(i,j,jj))
            m.append(index)
            flag = 1
        j+=1

# %%
# for i in df_F5['JD']: print(i)
df_F5.head()
# Out:
#         Unnamed: 0                       ID       WD        JD         GD  \
# 268370      268370  R2019081303584407603967  38.9042  124.3568  5162.1492
# 268371      268371  R2019081303584407603967  38.8842  124.3429  4968.0509
# 268372      268372  R2019081303584407603967  38.8649  124.3202  5430.0555
# 268373      268373  R2019081303584407603967  38.8390  124.3286  5338.3882
# 268374      268374  R2019081303584407603967  38.8123  124.3198  5006.2216
#
#               SD                 SJ target
# 268370  679.3993  2012/2/1 10:01:54    F-5
# 268371  661.6462  2012/2/1 10:02:04    F-5
# 268372  697.9918  2012/2/1 10:02:14    F-5
# 268373  671.5295  2012/2/1 10:02:24    F-5
# 268374  738.5973  2012/2/1 10:02:34    F-5

# %%
m.sort()

# %%
df_new = df_F5[0:0]
for i in m:
#     df_new = pd.concat([df_new, df_F5[i-1:i]], axis=1)
    df_new = df_new.append(df_F5[i-1:i])

# %%
df_new.to_csv('F-5聚类290条数据.csv')

# %%
upload = UPLOAD()

# %%
upload.dian(k                                                                     means_centers, 'kmeans')

# %% [markdown]
# # DBSCAN

# %%
df_F1['ID'].describe()
88657/100
# Out:
# 886.57

# %% [markdown]
# # F-1

# %%
import tqdm                                                                                                                                                           
num = 886
#df_F1 = df[df['target']='F-1'] #                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ='F-1']
df_F1 = df[df['target']=='F-1']
df_F1['JD'] = df_F1['JD'].astype(float)
df_F1['SD'] = df_F1['SD'].astype(float)
df_F1['GD'] = df_F1['GD'].astype(float)
df_F1['WD'] = df_F1['WD'].astype(float)
pass

df_F1_JD_WD = df_F1[['JD','WD']]
df_F1_JD_WD.info()
                                                                                                                                                                                                                                                 
trainX = df_F1_JD_WD.values
trainX.shape


from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=num)
kmeans.fit(trainX)

kmeans_centers = pd.DataFrame(kmeans.cluster_centers_)
kmeans_centers.columns = ['JD', 'WD']
# Out:
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import tqdm
m = list()
j = 0
for i in tqdm.tqdm(range(len(kmeans_centers['JD']))):
    JD = kmeans_centers['JD'][i]
    WD = kmeans_centers['WD'][i]
    flag = 0
    j = 0
    for index, jj in enumerate(df_F1['JD']):
#         print("{}".format(jj))
        precision = 0.002
        if abs(JD-jj)<precision:
            if abs(df_F1.iloc[index]['WD']-WD)<precision:
                m.append(index)
            flag = 1
        j+=1
        
m.sort()
print(len(m))
df_new = df_F1[0:0]
for i in m:
#     df_new = pd.concat([df_new, df_F1[i-1:i]], axis=1)
    df_new = df_new.append(df_F1[i-1:i])
df_new.to_csv('F-1聚类'+str(len(m))+'条数据.csv')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 886/886 [01:16<00:00, 11.60it/s]
# 1154

# %% [markdown]
# # F-2

# %%
import tqdm
df_F2 = df[df['target']=='F-2']
num = int(df_F2['ID'].describe()['count']/df_F2['ID'].describe()['unique'])
print("num is {}".format(num))
df_F2['JD'] = df_F2['JD'].astype(float)
df_F2['SD'] = df_F2['SD'].astype(float)
df_F2['GD'] = df_F2['GD'].astype(float)
df_F2['WD'] = df_F2['WD'].astype(float)
# Out:
# num is 832
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_F2_JD_WD = df_F2[['JD','WD']]
df_F2_JD_WD.info()
                                                                                                                                                                                                                                                 
trainX = df_F2_JD_WD.values
trainX.shape


from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=num)
kmeans.fit(trainX)

kmeans_centers = pd.DataFrame(kmeans.cluster_centers_)
kmeans_centers.columns = ['JD', 'WD']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83249 entries, 88657 to 171905
# Data columns (total 2 columns):
# JD    83249 non-null float64
# WD    83249 non-null float64
# dtypes: float64(2)
# memory usage: 1.9 MB

# %%
import tqdm
m = list()
j = 0
for i in tqdm.tqdm(range(len(kmeans_centers['JD']))):
    JD = kmeans_centers['JD'][i]
    WD = kmeans_centers['WD'][i]
    flag = 0
    j = 0
    for index, jj in enumerate(df_F2['JD']):
        precision = 0.002
        if abs(JD-jj)<precision:
#             print(jj)
            if abs(df_F2.iloc[index]['WD']-WD)<precision:
                m.append(index)
            flag = 1
        j+=1
        
m.sort()
print(len(m))
df_new = df_F2[0:0]
for i in m:
#     df_new = pd.concat([df_new, df_F2[i-1:i]], axis=1)
    df_new = df_new.append(df_F2[i-1:i])
df_new.to_csv('F-2聚类'+str(len(m))+'条数据.csv')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 832/832 [01:13<00:00, 11.29it/s]
# 1162

# %%
df_F2.iloc[3214]
# Out:
# Unnamed: 0                      91871
# ID            R2019081303584231302299
# WD                            28.5079
# JD                             125.86
# GD                             4787.2
# SD                            723.267
# SJ                 2012/2/25 12:14:37
# target                            F-2
# Name: 91871, dtype: object

# %% [markdown]
# # F-3

# %%
import tqdm
df_F3 = df[df['target']=='F-3']
num = int(df_F3['ID'].describe()['count']/df_F3['ID'].describe()['unique'])
print("num is {}".format(num))
df_F3['JD'] = df_F3['JD'].astype(float)
df_F3['SD'] = df_F3['SD'].astype(float)
df_F3['GD'] = df_F3['GD'].astype(float)
df_F3['WD'] = df_F3['WD'].astype(float)

df_F3_JD_WD = df_F3[['JD','WD']]
df_F3_JD_WD.info()
                                                                                                                                                                                                                                                 
trainX = df_F3_JD_WD.values
trainX.shape


from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=num)
kmeans.fit(trainX)

kmeans_centers = pd.DataFrame(kmeans.cluster_centers_)
kmeans_centers.columns = ['JD', 'WD']

import tqdm
m = list()
j = 0
for i in tqdm.tqdm(range(len(kmeans_centers['JD']))):
    JD = kmeans_centers['JD'][i]
    WD = kmeans_centers['WD'][i]
    flag = 0
    j = 0
    for index, jj in enumerate(df_F3['JD']):
        precision = 0.002
        if abs(JD-jj)<precision:
#             print(jj)
            if abs(df_F3.iloc[index]['WD']-WD)<precision:
                m.append(index)
            flag = 1
        j+=1
        
m.sort()
print(len(m))
df_new = df_F3[0:0]
for i in m:
#     df_new = pd.concat([df_new, df_F3[i-1:i]], axis=1)
    df_new = df_new.append(df_F3[i-1:i])
df_new.to_csv('F-3聚类'+str(len(m))+'条数据.csv')
# Out:
# num is 912
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # F-4

# %%
import tqdm
df_F4 = df[df['target']=='F-4']
num = int(df_F4['ID'].describe()['count']/df_F4['ID'].describe()['unique'])
print("num is {}".format(num))
df_F4['JD'] = df_F4['JD'].astype(float)
df_F4['SD'] = df_F4['SD'].astype(float)
df_F4['GD'] = df_F4['GD'].astype(float)
df_F4['WD'] = df_F4['WD'].astype(float)

df_F4_JD_WD = df_F4[['JD','WD']]
df_F4_JD_WD.info()
                                                                                                                                                                                                                                                 
trainX = df_F4_JD_WD.values
trainX.shape


from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=num)
kmeans.fit(trainX)

kmeans_centers = pd.DataFrame(kmeans.cluster_centers_)
kmeans_centers.columns = ['JD', 'WD']
# Out:
# num is 520
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import tqdm
m = list()
j = 0
for i in tqdm.tqdm(range(len(kmeans_centers['JD']))):
    JD = kmeans_centers['JD'][i]
    WD = kmeans_centers['WD'][i]
    flag = 0
    j = 0
    for index, jj in enumerate(df_F4['JD']):
        precision = 0.004
        if abs(JD-jj)<precision:
#             print(jj)
            if abs(df_F4.iloc[index]['WD']-WD)<precision:
                m.append(index)
            flag = 1
        j+=1
        
m.sort()
print(len(m))
df_new = df_F4[0:0]
for i in m:
#     df_new = pd.concat([df_new, df_F4[i-1:i]], axis=1)
    df_new = df_new.append(df_F4[i-1:i])
df_new.to_csv('F-4聚类'+str(len(m))+'条数据.csv')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 520/520 [00:03<00:00, 145.03it/s]
# 311

# %% [markdown]
# # F-6

# %%
import tqdm
df_F6 = df[df['target']=='F-6']
num = int(df_F6['ID'].describe()['count']/df_F6['ID'].describe()['unique'])
print("num is {}".format(num))
df_F6['JD'] = df_F6['JD'].astype(float)
df_F6['SD'] = df_F6['SD'].astype(float)
df_F6['GD'] = df_F6['GD'].astype(float)
df_F6['WD'] = df_F6['WD'].astype(float)

df_F6_JD_WD = df_F6[['JD','WD']]
df_F6_JD_WD.info()
                                                                                                                                                                                                                                                 
trainX = df_F6_JD_WD.values
trainX.shape


from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=num)
kmeans.fit(trainX)

kmeans_centers = pd.DataFrame(kmeans.cluster_centers_)
kmeans_centers.columns = ['JD', 'WD']
# Out:
# num is 473
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import tqdm
m = list()
j = 0
for i in tqdm.tqdm(range(len(kmeans_centers['JD']))):
    JD = kmeans_centers['JD'][i]
    WD = kmeans_centers['WD'][i]
    flag = 0
    j = 0
    for index, jj in enumerate(df_F6['JD']):
        precision = 0.005
        if abs(JD-jj)<precision:
#             print(jj)
            if abs(df_F6.iloc[index]['WD']-WD)<precision:
                m.append(index)
            flag = 1
        j+=1
        
m.sort()
print(len(m))
df_new = df_F6[0:0]
for i in m:
#     df_new = pd.concat([df_new, df_F6[i-1:i]], axis=1)
    df_new = df_new.append(df_F6[i-1:i])
df_new.to_csv('F-6聚类'+str(len(m))+'条数据.csv')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 473/473 [00:04<00:00, 100.31it/s]
# 438

# %% [markdown]
# # F-7

# %%
import tqdm
df_F7 = df[df['target']=='F-7']
num = int(df_F7['ID'].describe()['count']/df_F7['ID'].describe()['unique'])
print("num is {}".format(num))
df_F7['JD'] = df_F7['JD'].astype(float)
df_F7['SD'] = df_F7['SD'].astype(float)
df_F7['GD'] = df_F7['GD'].astype(float)
df_F7['WD'] = df_F7['WD'].astype(float)

df_F7_JD_WD = df_F7[['JD','WD']]
df_F7_JD_WD.info()
                                                                                                                                                                                                                                                 
trainX = df_F7_JD_WD.values
trainX.shape


from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=num)
kmeans.fit(trainX)

kmeans_centers = pd.DataFrame(kmeans.cluster_centers_)
kmeans_centers.columns = ['JD', 'WD']
# Out:
# num is 507
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\02_prosoftware\anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import tqdm
m = list()
j = 0
for i in tqdm.tqdm(range(len(kmeans_centers['JD']))):
    JD = kmeans_centers['JD'][i]
    WD = kmeans_centers['WD'][i]
    flag = 0
    j = 0
    for index, jj in enumerate(df_F7['JD']):
        precision = 0.006
        if abs(JD-jj)<precision:
#             print(jj)
            if abs(df_F7.iloc[index]['WD']-WD)<precision:
                m.append(index)
            flag = 1
        j+=1
        
m.sort()
print(len(m))
df_new = df_F7[0:0]
for i in m:
#     df_new = pd.concat([df_new, df_F7[i-1:i]], axis=1)
    df_new = df_new.append(df_F7[i-1:i])
df_new.to_csv('F-7聚类'+str(len(m))+'条数据.csv')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 507/507 [00:02<00:00, 177.19it/s]
# 655

# %%
for i in range(1,8):
    df_F7 = df[df['target']=='F-'+str(i)]
    num = int(df_F7['ID'].describe()['count']/df_F7['ID'].describe()['unique'])
    print("{} is {}".format(i,num))
# Out:
# 1 is 886
# 2 is 832
# 3 is 912
# 4 is 520
# 5 is 270
# 6 is 473
# 7 is 507
